# %%
import tensorflow as tf 

with tf.Session() as sess:

    # rank 0 tensor: a scalar
    mammal = tf.Variable('Elephant', tf.string)
    ignition = tf.Variable(123, tf.int16)
    floating = tf.Variable(7.7123456789, tf.float64)
    print('examples of rank 0 tensors')
    print('rank of string scalar ', sess.run(tf.rank(mammal)))
    print('rank of int scalar ', sess.run(tf.rank(ignition)))
    print('rank of float scalar', sess.run(tf.rank(floating)))
    print()

    # rank 1 tensor: vector 
    complex_number = tf.Variable((12.3, -4.85), tf.complex64)
    str_value = tf.Variable(['Hello'], tf.string)
    float_numbers = tf.Variable([1.23, 3.45, 6.78], tf.float32)
    int_numbers = tf.Variable([1, 2, 3, 4, 5, 6, 7], tf.int32)
    print('examples of rank 1 tensors')
    print('rank of complex numner ', sess.run(tf.rank(complex_number)))
    print('rank of string vector ', sess.run(tf.rank(str_value)))
    print('rank of float vector', sess.run(tf.rank(float_numbers)))
    print('rank of int vector ', sess.run(tf.rank(int_numbers)))
    print()

    # rank 2 tensor: matrix
    complex_numbers = tf.Variable([(1.23, 4.56), (7.54, 8.34)], tf.complex64)
    int_matrix = tf.Variable([[1], [2]], tf.int16)
    myxor = tf.Variable([[False, True], [True, False]], tf.bool)
    linear_square = tf.Variable([[2], [9], [12], [25], [36]], tf.int32)
    squarish_squares = tf.Variable([[4, 9], [16, 25]], tf.int32)
    print('examples of rank 2 tensors')
    print('rank of complex number vector ', sess.run(tf.rank(complex_numbers)))
    print('rank of int matrix ', sess.run(tf.rank(int_matrix)))
    print('rank of boolean matrix ', sess.run(tf.rank(myxor)))
    print('rank of int matrix ', sess.run(tf.rank(linear_square)))
    print('rank of int matrix ', sess.run(tf.rank(squarish_squares)))
    print()

    # n rank tensor 
    # example of 10 images, 299x299 with 3 color channel 
    image_list = tf.zeros([10, 299, 299, 3])
    second_image_list = tf.zeros(sess.run(tf.shape(image_list)))
    print('example of n rank tensors')
    print('rank of 4 dimension tensor ', sess.run(tf.rank(image_list)))
    print('shape of tensor ', image_list.shape)
    print('shape of second image list copy from image_list ', second_image_list.shape)
    print()

    # 60 elements 3-dimension 
    rank_three_tensor = tf.ones([3, 4, 5])
    # 60 elements matrix 
    matrix = tf.reshape(rank_three_tensor, [6, 10])
    # -1 to tell reshape to calculate the size of this demension 
    # the result still 60 elements matrix 
    matrix_3_row = tf.reshape(matrix, [3, -1])
    matrix_4_3_5 = tf.reshape(matrix_3_row, [4, 3, -1])
    print('reshape tensors')
    print('original tensor shape ', rank_three_tensor.shape)
    print('reshape to matrix ', matrix.shape)
    print('reshape to 3 row matrix ', matrix_3_row.shape)
    print('reshape to 4x3x5 tensor ', matrix_4_3_5.shape)
# Out:
# examples of rank 0 tensors
# ('rank of string scalar ', 0)
# ('rank of int scalar ', 0)
# ('rank of float scalar', 0)
# ()
# examples of rank 1 tensors
# ('rank of complex numner ', 1)
# ('rank of string vector ', 1)
# ('rank of float vector', 1)
# ('rank of int vector ', 1)
# ()
# examples of rank 2 tensors
# ('rank of complex number vector ', 2)
# ('rank of int matrix ', 2)
# ('rank of boolean matrix ', 2)
# ('rank of int matrix ', 2)
# ('rank of int matrix ', 2)
# ()
# example of n rank tensors
# ('rank of 4 dimension tensor ', 4)
# ('shape of tensor ', TensorShape([Dimension(10), Dimension(299), Dimension(299), Dimension(3)]))
# ('shape of second image list copy from image_list ', TensorShape([Dimension(10), Dimension(299), Dimension(299), Dimension(3)]))
# ()
# reshape tensors
# ('original tensor shape ', TensorShape([Dimension(3), Dimension(4), Dimension(5)]))
# ('reshape to matrix ', TensorShape([Dimension(6), Dimension(10)]))
# ('reshape to 3 row matrix ', TensorShape([Dimension(3), Dimension(20)]))
# ('reshape to 4x3x5 tensor ', TensorShape([Dimension(4), Dimension(3), Dimension(5)]))

# %%
my_variable
# define variable 
# create variable named 'my_variable' with shape [1, 2, 3], default type tf.float32
#my_variable = tf.get_variable('my_variable', [1, 2, 3])

my_int_variable = tf.get_variable('my_int_variable', dtype=tf.int32, shape=[1, 2, 3], constraint=None, initializer=tf.zeros_initializer)

other_variable = tf.get_variable('other_variable', dtype=tf.int32, initializer=tf.constant([23, 42]))

# variable collections 
# by default tf.Variable place in collections: tf.GraphKeys.GLOBAL_VARIABLES, tf.GraphKeys.TRAINABLE_VARIABLES
# to create local variable 
my_local = tf.get_variable('my_local', shape=[1, 2, 3], collections=[tf.GraphKeys.LOCAL_VARIABLES])

# to create non trainable variable 
my_non_trainable = tf.get_variable('my_non_trainable', shape=[1, 2, 3], trainable=False)

# define custom collection 
tf.add_to_collection('my_new_collection', my_local)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-11-930ef07d4167> in <module>()
#       4 #my_variable = tf.get_variable('my_variable', [1, 2, 3])
#       5
# ----> 6 my_int_variable = tf.get_variable('my_int_variable', dtype=tf.int32, shape=[1, 2, 3], constraint=None, initializer=tf.zeros_initializer)
#       7
#       8 other_variable = tf.get_variable('other_variable', dtype=tf.int32, initializer=tf.constant([23, 42]))
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#    1295       partitioner=partitioner, validate_shape=validate_shape,
#    1296       use_resource=use_resource, custom_getter=custom_getter,
# -> 1297       constraint=constraint)
#    1298 get_variable_or_local_docstring = (
#    1299     """%s
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#    1091           partitioner=partitioner, validate_shape=validate_shape,
#    1092           use_resource=use_resource, custom_getter=custom_getter,
# -> 1093           constraint=constraint)
#    1094
#    1095   def _get_partitioned_variable(self,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#     437           caching_device=caching_device, partitioner=partitioner,
#     438           validate_shape=validate_shape, use_resource=use_resource,
# --> 439           constraint=constraint)
#     440
#     441   def _get_partitioned_variable(
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/variable_scope.pyc in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint)
#     406           trainable=trainable, collections=collections,
#     407           caching_device=caching_device, validate_shape=validate_shape,
# --> 408           use_resource=use_resource, constraint=constraint)
#     409
#     410     if custom_getter is not None:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/variable_scope.pyc in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint)
#     745                          "reuse=tf.AUTO_REUSE in VarScope? "
#     746                          "Originally defined at:\n\n%s" % (
# --> 747                              name, "".join(traceback.format_list(tb))))
#     748       found_var = self._vars[name]
#     749       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable my_int_variable already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "<ipython-input-3-ef79ab59a769>", line 7, in <module>
#     my_int_variable = tf.get_variable('my_int_variable', dtype=tf.int32, shape=[1, 2, 3], initializer=tf.zeros_initializer)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
