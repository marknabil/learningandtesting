# %% [markdown]
# # Data augmentation

# %% [markdown]
# ## Problem Statement and introducion

# %% [markdown]
# *   [Paper about the issue from google and stanford](http://cs231n.stanford.edu/reports/2017/pdfs/300.pdf)
# *   [Blog post with tensorflow examples](https://medium.com/ymedialabs-innovation/data-augmentation-techniques-in-cnn-using-tensorflow-371ae43d5be9)
# * [a snippit on github](https://github.com/krshrimali/Data-Augmentation-using-Tensorflow/blob/master/resizing.py)
# * [a library for image augmentation in Python](https://github.com/aleju/imgaug)
# *  [example on openMV](https://github.com/openmv/openmv/blob/master/tools/augment_images.py)
