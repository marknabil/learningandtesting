# %% [markdown]
# websites:
#
#
# *   http://openmdao.org/  ,
#
# *   https://github.com/google/or-tools

# %% [markdown]
# ## packages installation

# %%
# !pip install openmdao
# Out:
# Collecting openmdao
#   Downloading https://files.pythonhosted.org/packages/87/f7/e63a0bf172a302db6f33703e0ba30f023c444caf087683c6b968405adc81/openmdao-2.6.0.tar.gz (1.1MB)
#     100% |████████████████████████████████| 1.1MB 21.2MB/s
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from openmdao) (2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from openmdao) (1.14.6)
# Collecting pyDOE2 (from openmdao)
#   Downloading https://files.pythonhosted.org/packages/af/4b/629d865a76ba54f187d2eadf33ff17d9279019aa15a5e642a4f87aa3a4b5/pyDOE2-1.1.2.tar.gz
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from openmdao) (2.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from openmdao) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from openmdao) (1.11.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->openmdao) (4.3.2)
# Building wheels for collected packages: openmdao, pyDOE2
#   Building wheel for openmdao (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/8d/fc/c3/ea741c3b2a7d012a123311adf2878da5a914d8b6e58a13bf2e
#   Building wheel for pyDOE2 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/01/91/ef/ae4d3e0d97d40f4620bcc24a51bad574ef67b8b38426fd873d
# Successfully built openmdao pyDOE2
# Installing collected packages: pyDOE2, openmdao
# Successfully installed openmdao-2.6.0 pyDOE2-1.1.2

# %%
from openmdao.api import Problem, ScipyOptimizeDriver, ExecComp, IndepVarComp 

# build the model 
prob = Problem() 
indeps = prob.model.add_subsystem('indeps', IndepVarComp()) 
indeps.add_output('x', 3.0) 
indeps.add_output('y', -4.0) 

prob.model.add_subsystem('paraboloid', ExecComp('f = (x-3)**2 + x*y + (y+4)**2 - 3')) 

prob.model.connect('indeps.x', 'paraboloid.x') 
prob.model.connect('indeps.y', 'paraboloid.y') 

prob.driver = ScipyOptimizeDriver() 
prob.driver.options['optimizer'] = 'SLSQP' 

prob.model.add_design_var('indeps.x', lower=-50, upper=50) 
prob.model.add_design_var('indeps.y', lower=-50, upper=50) 
prob.model.add_objective('paraboloid.f') 

prob.setup() 
prob.run_driver() 

# minimum value 
print(prob['paraboloid.f']) 
# location of the minimum 
print(prob['indeps.x']) 
print(prob['indeps.y'])
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -27.33333333333333
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Optimization Complete
# -----------------------------------
# [-27.33333333]
# [6.66666667]
# [-7.33333333]

# %%
# !pip install PyCpuSimulator
# Out:
# Collecting PyCpuSimulator
#   Downloading https://files.pythonhosted.org/packages/81/ee/882ab488b5cb2323e28dc6fb4004e78bdea4a8901055fdb13b8feff936f6/PyCpuSimulator-0.2.1-py2.py3-none-any.whl (41kB)
#     100% |████████████████████████████████| 51kB 4.1MB/s
# Collecting ply (from PyCpuSimulator)
#   Downloading https://files.pythonhosted.org/packages/a3/58/35da89ee790598a0700ea49b2a66594140f44dec458c07e8e3d4979137fc/ply-3.11-py2.py3-none-any.whl (49kB)
#     100% |████████████████████████████████| 51kB 21.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from PyCpuSimulator) (1.14.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from PyCpuSimulator) (3.13)
# Collecting ansicolor (from PyCpuSimulator)
#   Downloading https://files.pythonhosted.org/packages/42/0b/f370fae6d0070758e8bbf46c77da779e4ea79870ea5197893b2678848aeb/ansicolor-0.2.6-py2.py3-none-any.whl
# Installing collected packages: ply, ansicolor, PyCpuSimulator
# Successfully installed PyCpuSimulator-0.2.1 ansicolor-0.2.6 ply-3.11
