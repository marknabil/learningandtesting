# %% [markdown]
# # Modern Robotics book

# %% [markdown]
# [modern robotics github](https://github.com/NxRLab/ModernRobotics)
#
# [Modern robotics online book](http://hades.mech.northwestern.edu/index.php/Modern_Robotics)
#
# Manual : https://github.com/NxRLab/ModernRobotics/blob/master/doc/MRlib.pdf

# %%
# !pip install modern_robotics
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/27/33/0f/f3dbd52f320b5a427a8e7ab58ce0f8bb0d64e362108f4b81f0
# Successfully built modern-robotics
# ...

# %%
import modern_robotics as mr
import numpy as np

# %%
help(mr.RotInv)
# Out:
# Help on function RotInv in module modern_robotics.core:
#
# RotInv(R)
#     Inverts a rotation matrix
#
#     :param R: A rotation matrix
#     :return: The inverse of R
#
#     Example Input:
#         R = np.array([[0, 0, 1],
#                       [1, 0, 0],
#                       [0, 1, 0]])
#     Output:
#         np.array([[0, 1, 0],
#                   [0, 0, 1],
#                   [1, 0, 0]])

# %%
#R=[[1,0,2],[0,3,2],[2,0,3]]
Y = np.array([[0, 3, 1],
                      [1, 0, 0],
                      [0, 1, 0]])
distance_to_point=mr.DistanceToSO3(Y)
print(distance_to_point)
# Out:
# 9.9498743710662

# %% [markdown]
# # chapter 3

# %%
mr.MatrixExp3()

# %%
so3mat = mr.so3ToVec()
