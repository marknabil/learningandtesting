# %% [markdown]
# https://github.com/pms67/Attitude-Estimation

# %%
# !git clone https://github.com/pms67/Attitude-Estimation
# Out:
# Cloning into 'Attitude-Estimation'...
# remote: Enumerating objects: 62, done.
# remote: Total 62 (delta 0), reused 0 (delta 0), pack-reused 62
# Unpacking objects: 100% (62/62), done.

# %%
# !ls Attitude-Estimation/
# Out:
# attitude_estimation.m  gyro_drift.m  imu.py	    LICENSE
# complimentary_imu.py   imu_data.csv  kalman_imu.py  README.md

# %%
# !pip install smbus
# Out:
# ...
#     100% |████████████████████████████████| 112kB 2.8MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/5e/04/0f/92b5c05ceb35607205c025dc55dbb766b7fb9dc7f0423dc2b2
# Successfully built smbus
# ...

# %%
# !python Attitude-Estimation/kalman_imu.py
# Out:
# Traceback (most recent call last):
#   File "Attitude-Estimation/kalman_imu.py", line 11, in <module>
#     imu = IMU()
#   File "/content/Attitude-Estimation/imu.py", line 13, in __init__
#     self.bus = smbus.SMBus(1)
# FileNotFoundError: [Errno 2] No such file or directory
